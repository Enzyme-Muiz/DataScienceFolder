# %% [markdown]
# # ANALYSIS OF {DATA}

# %% [markdown]
# ## CLEANING AND VISUALIZATION

# %% [markdown]
# ## STATISTICAL ANALYSIS

# %% [markdown]
# ## MODELLING AND/OR FORECASTING

# %% [markdown]
# ### PREPROCESSING

# %% [markdown]
# ### MODEL TRAINING

# %% [markdown]
# ### PERFORMANCE EVALUATION

# %% [markdown]
# ### PREDICTION

# %% [markdown]
# ### SAVE THE MODEL
